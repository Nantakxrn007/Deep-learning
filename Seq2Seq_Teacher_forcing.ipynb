# %% [markdown]
# <a href="https://colab.research.google.com/github/Eieiz007/Deep-learning/blob/main/Seq2Seq_Teacher_forcing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam , AdamW
from tensorflow.keras.layers import Input, LSTM, Dense
import matplotlib.pyplot as plt

# %% [markdown]
# # Create data

# %%
date_range = pd.date_range(start="2023-01-01", end="2025-12-31", freq="D") #วันที่ 2 ปี

days = np.arange(len(date_range))
temperature = 25 + 5 * np.sin(2 * np.pi * days / 365) + np.random.normal(0, 2, len(days))
humidity = 60 + 10 * np.cos(2 * np.pi * days / 365) + np.random.normal(0, 5, len(days))
np.random.seed(42)

df = pd.DataFrame({
    "date": date_range,
    "temperature": temperature,
    "humidity": humidity
})

# แสดงตัวอย่างข้อมูล
df.head(10)
# Out:
#         date  temperature   humidity
# 0 2023-01-01    25.993428  70.393176
# 1 2023-01-02    24.809538  60.007515
# 2 2023-01-03    26.467485  74.575712
# 3 2023-01-04    28.304158  71.719111
# 4 2023-01-05    24.875705  74.966354
# 5 2023-01-06    24.961550  55.481705
# 6 2023-01-07    28.673934  80.388582
# 7 2023-01-08    27.135910  69.229539
# 8 2023-01-09    24.747445  75.446239
# 9 2023-01-10    26.856664  64.680697

# %%
df.iloc[:,1:].hist(figsize=(10,2))
# Out:
# array([[<Axes: title={'center': 'temperature'}>,
#         <Axes: title={'center': 'humidity'}>]], dtype=object)

# %%
plt.plot(df['date'], df['temperature'])
plt.plot(df['date'], df['humidity'])

# %% [markdown]
# # Data prepartation for train model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
len(df)
# Out:
# 1096

# %%
encoder_timesteps = 5  # ใช้ข้อมูลย้อนหลัง 30 วัน
decoder_timesteps = 2    # ทำนายอนาคต 7 วัน

X_encoder, Y_decoder_input, Y_decoder_output = [], [], []

for i in range(len(df) - encoder_timesteps - decoder_timesteps):
    # Encoder input (5 วันก่อนหน้า)          # 0 1 2 3 4
    X_encoder.append(df.iloc[i : i + encoder_timesteps][["temperature", "humidity"]].values)

    # Decoder input (ใช้ค่าจริงของ 2 วันถัดไป) # 4 5
    Y_decoder_input.append(df.iloc[i + encoder_timesteps-1 : (i + encoder_timesteps-1) + decoder_timesteps][["temperature", "humidity"]].values)

    # Decoder output (ค่าที่ต้องทำนาย)       # 5 6
    Y_decoder_output.append(df.iloc[i + encoder_timesteps: i + encoder_timesteps + decoder_timesteps][["temperature", "humidity"]].values)

# แปลงเป็น NumPy array
X_encoder = np.array(X_encoder)
Y_decoder_input = np.array(Y_decoder_input)
Y_decoder_output = np.array(Y_decoder_output)

# ตรวจสอบขนาดของข้อมูล
X_encoder.shape, Y_decoder_input.shape, Y_decoder_output.shape
# Out:
# ((1089, 5, 2), (1089, 2, 2), (1089, 2, 2))

# %%
X_encoder[:3] , '**********************************************', Y_decoder_input[:1], '**********************************************', Y_decoder_output[:1]
# Out:
# (array([[[25.99342831, 70.39317595],
#          [24.80953818, 60.00751497],
#          [26.46748513, 74.57571238],
#          [28.30415805, 71.71911054],
#          [24.87570538, 74.9663536 ]],
#
#         [[24.80953818, 60.00751497],
#          [26.46748513, 74.57571238],
#          [28.30415805, 71.71911054],
#          [24.87570538, 74.9663536 ],
#          [24.96155008, 55.48170486]],
#
#         [[26.46748513, 74.57571238],
#          [28.30415805, 71.71911054],
#          [24.87570538, 74.9663536 ],
#          [24.96155008, 55.48170486],
#          [28.67393412, 80.38858172]]]),
#  '**********************************************',
#  array([[[24.87570538, 74.9663536 ],
#          [24.96155008, 55.48170486]]]),
#  '**********************************************',
#  array([[[24.96155008, 55.48170486],
#          [28.67393412, 80.38858172]]]))

# %% [markdown]
# # Data splitting and Normalization

# %%
X_train_enc, X_temp_enc    , Y_train_dec_in, Y_temp_dec_in ,     Y_train_dec_out, Y_temp_dec_out = train_test_split(
    X_encoder, Y_decoder_input, Y_decoder_output
    , test_size=0.3, shuffle=False
)

X_val_enc, X_test_enc,       Y_val_dec_in, Y_test_dec_in,       Y_val_dec_out, Y_test_dec_out = train_test_split(
    X_temp_enc, Y_temp_dec_in, Y_temp_dec_out
    , test_size=0.5, shuffle=False
)

print("Encoder Input Shapes:")
print(f"X_train_enc: {X_train_enc.shape}")
print(f"X_val_enc: {X_val_enc.shape}")
print(f"X_test_enc: {X_test_enc.shape}")

print("\nDecoder Input Shapes:")
print(f"Y_train_dec_in: {Y_train_dec_in.shape}")
print(f"Y_val_dec_in: {Y_val_dec_in.shape}")
print(f"Y_test_dec_in: {Y_test_dec_in.shape}")

print("\nDecoder Output Shapes:")
print(f"Y_train_dec_out: {Y_train_dec_out.shape}")
print(f"Y_val_dec_out: {Y_val_dec_out.shape}")
print(f"Y_test_dec_out: {Y_test_dec_out.shape}")
# Out:
# Encoder Input Shapes:
# X_train_enc: (762, 5, 2)
# X_val_enc: (163, 5, 2)
# X_test_enc: (164, 5, 2)
#
# Decoder Input Shapes:
# Y_train_dec_in: (762, 2, 2)
# Y_val_dec_in: (163, 2, 2)
# Y_test_dec_in: (164, 2, 2)
#
# Decoder Output Shapes:
# Y_train_dec_out: (762, 2, 2)
# Y_val_dec_out: (163, 2, 2)
# Y_test_dec_out: (164, 2, 2)

# %%
scaler_enc = MinMaxScaler()
scaler_dec = MinMaxScaler()

X_train_enc_scaled = scaler_enc.fit_transform(X_train_enc.reshape(-1, X_train_enc.shape[-1])).reshape(X_train_enc.shape)
X_val_enc_scaled = scaler_enc.transform(X_val_enc.reshape(-1, X_val_enc.shape[-1])).reshape(X_val_enc.shape)
X_test_enc_scaled = scaler_enc.transform(X_test_enc.reshape(-1, X_test_enc.shape[-1])).reshape(X_test_enc.shape)

Y_train_dec_in_scaled = scaler_dec.fit_transform(Y_train_dec_in.reshape(-1, Y_train_dec_in.shape[-1])).reshape(Y_train_dec_in.shape)
Y_val_dec_in_scaled = scaler_dec.transform(Y_val_dec_in.reshape(-1, Y_val_dec_in.shape[-1])).reshape(Y_val_dec_in.shape)
Y_test_dec_in_scaled = scaler_dec.transform(Y_test_dec_in.reshape(-1, Y_test_dec_in.shape[-1])).reshape(Y_test_dec_in.shape)

Y_train_dec_out_scaled = scaler_dec.transform(Y_train_dec_out.reshape(-1, Y_train_dec_out.shape[-1])).reshape(Y_train_dec_out.shape)
Y_val_dec_out_scaled = scaler_dec.transform(Y_val_dec_out.reshape(-1, Y_val_dec_out.shape[-1])).reshape(Y_val_dec_out.shape)
Y_test_dec_out_scaled = scaler_dec.transform(Y_test_dec_out.reshape(-1, Y_test_dec_out.shape[-1])).reshape(Y_test_dec_out.shape)

print("After MinMax Scaling:")
print(f"X_train_enc_scaled: {X_train_enc_scaled.shape}")
print(f"X_val_enc_scaled: {X_val_enc_scaled.shape}")
print(f"X_test_enc_scaled: {X_test_enc_scaled.shape}")
print(f"Y_train_dec_in_scaled: {Y_train_dec_in_scaled.shape}")
print(f"Y_val_dec_in_scaled: {Y_val_dec_in_scaled.shape}")
print(f"Y_test_dec_in_scaled: {Y_test_dec_in_scaled.shape}")
print(f"Y_train_dec_out_scaled: {Y_train_dec_out_scaled.shape}")
print(f"Y_val_dec_out_scaled: {Y_val_dec_out_scaled.shape}")
print(f"Y_test_dec_out_scaled: {Y_test_dec_out_scaled.shape}")
# Out:
# After MinMax Scaling:
# X_train_enc_scaled: (762, 5, 2)
# X_val_enc_scaled: (163, 5, 2)
# X_test_enc_scaled: (164, 5, 2)
# Y_train_dec_in_scaled: (762, 2, 2)
# Y_val_dec_in_scaled: (163, 2, 2)
# Y_test_dec_in_scaled: (164, 2, 2)
# Y_train_dec_out_scaled: (762, 2, 2)
# Y_val_dec_out_scaled: (163, 2, 2)
# Y_test_dec_out_scaled: (164, 2, 2)

# %% [markdown]
# # Train model

# %%
# config
latent_dim = 256  # ขนาดของ hidden state ใน LSTM
encoder_timesteps = X_train_enc.shape[1]
decoder_timesteps = Y_train_dec_in.shape[1]
n_features = X_train_enc.shape[2]

# ===== Encoder =====
encoder_inputs = Input(shape=(encoder_timesteps, n_features))
encoder_lstm = LSTM(latent_dim, return_sequences=False, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_inputs)
encoder_states = [state_h, state_c]

# ===== Decoder =====
decoder_inputs = Input(shape=(decoder_timesteps, n_features))
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _ , _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)

# ===== Fully Connected Layer (เพิ่มตรงนี้) =====
decoder_dense1 = Dense(64, activation="gelu")(decoder_outputs)  #Dense 1
decoder_dense2 = Dense(32, activation="gelu")(decoder_dense1)  # Dense 2
decoder_dense3 = Dense(n_features, activation="linear")(decoder_dense2)  # Dense output


# ===== Seq2Seq Model =====
model = Model([encoder_inputs, decoder_inputs], decoder_dense3)
model.compile(optimizer=AdamW(learning_rate=0.00001), loss="mse")
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_11            │ (None, 5, 2)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_12            │ (None, 2, 2)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_11 (LSTM)            │ [(None, 256), (None,   │        265,216 │ input_layer_11[0][0]   │
# │                           │ 256), (None, 256)]     │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_12 (LSTM)            │ [(None, 2, 256),       │        265,216 │ input_layer_12[0][0],  │
# │                           │ (None, 256), (None,    │                │ lstm_11[0][1],         │
# │                           │ 256)]                  │                │ lstm_11[0][2]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_14 (Dense)          │ (None, 2, 64)          │         16,448 │ lstm_12[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_15 (Dense)          │ (None, 2, 32)          │          2,080 │ dense_14[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_16 (Dense)          │ (None, 2, 2)           │             66 │ dense_15[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 549,026 (2.09 MB)
#  Trainable params: 549,026 (2.09 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# LSTM ออกมา 3 อย่าง output , h , c มันก็เลยเป็น shape 3 ตัว

# %%
history = model.fit(
    [X_train_enc_scaled, Y_train_dec_in_scaled], Y_train_dec_out_scaled,
    validation_data=([X_val_enc_scaled, Y_val_dec_in_scaled], Y_val_dec_out_scaled),
    epochs=100,
    batch_size=64
)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.2857 - val_loss: 0.3287
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2792 - val_loss: 0.3218
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2757 - val_loss: 0.3149
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2752 - val_loss: 0.3081
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.2655 - val_loss: 0.3013
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.2666 - val_loss: 0.2945
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.2515 - val_loss: 0.2878
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2510 - val_loss: 0.2809
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2422 - val_loss: 0.2739
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2366 - val_loss: 0.2668
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.2269 - val_loss: 0.2596
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2270 - val_loss: 0.2522
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2149 - val_loss: 0.2447
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2044 - val_loss: 0.2369
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2043 - val_loss: 0.2289
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.1960 - val_loss: 0.2207
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1875 - val_loss: 0.2122
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1794 - val_loss: 0.2035
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.1683 - val_loss: 0.1946
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1626 - val_loss: 0.1854
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.1566 - val_loss: 0.1759
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1451 - val_loss: 0.1663
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.1369 - val_loss: 0.1565
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.1269 - val_loss: 0.1465
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.1205 - val_loss: 0.1364
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1100 - val_loss: 0.1263
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.1000 - val_loss: 0.1162
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0940 - val_loss: 0.1062
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0836 - val_loss: 0.0965
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0768 - val_loss: 0.0873
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0667 - val_loss: 0.0785
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0628 - val_loss: 0.0704
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0544 - val_loss: 0.0632
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0483 - val_loss: 0.0569
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0420 - val_loss: 0.0516
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0379 - val_loss: 0.0473
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0338 - val_loss: 0.0438
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0305 - val_loss: 0.0412
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0288 - val_loss: 0.0393
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0276 - val_loss: 0.0378
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0264 - val_loss: 0.0367
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0262 - val_loss: 0.0357
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0263 - val_loss: 0.0350
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0252 - val_loss: 0.0343
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0258 - val_loss: 0.0337
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0256 - val_loss: 0.0332
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0251 - val_loss: 0.0327
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0254 - val_loss: 0.0322
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0257 - val_loss: 0.0319
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0254 - val_loss: 0.0315
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0245 - val_loss: 0.0311
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0248 - val_loss: 0.0308
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0250 - val_loss: 0.0306
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0250 - val_loss: 0.0303
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0248 - val_loss: 0.0301
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0239 - val_loss: 0.0298
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0244 - val_loss: 0.0297
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0251 - val_loss: 0.0295
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0241 - val_loss: 0.0293
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0237 - val_loss: 0.0292
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0242 - val_loss: 0.0290
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0237 - val_loss: 0.0288
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0240 - val_loss: 0.0287
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0240 - val_loss: 0.0287
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0246 - val_loss: 0.0285
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0236 - val_loss: 0.0284
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0236 - val_loss: 0.0282
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0234 - val_loss: 0.0281
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0231 - val_loss: 0.0281
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0240 - val_loss: 0.0279
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0232 - val_loss: 0.0279
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0236 - val_loss: 0.0277
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0232 - val_loss: 0.0277
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0234 - val_loss: 0.0274
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0229 - val_loss: 0.0274
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0226 - val_loss: 0.0273
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0231 - val_loss: 0.0272
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0232 - val_loss: 0.0272
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0233 - val_loss: 0.0271
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0229 - val_loss: 0.0270
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0227 - val_loss: 0.0268
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0226 - val_loss: 0.0267
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0222 - val_loss: 0.0266
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0230 - val_loss: 0.0266
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0229 - val_loss: 0.0265
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0225 - val_loss: 0.0263
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0226 - val_loss: 0.0263
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0223 - val_loss: 0.0262
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0219 - val_loss: 0.0261
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0222 - val_loss: 0.0260
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0217 - val_loss: 0.0259
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0216 - val_loss: 0.0258
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0214 - val_loss: 0.0257
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0218 - val_loss: 0.0256
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0212 - val_loss: 0.0256
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0218 - val_loss: 0.0254
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0207 - val_loss: 0.0253
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0215 - val_loss: 0.0252
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0220 - val_loss: 0.0250
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0215 - val_loss: 0.0250

# %%
# ===== Plot กราฟ Loss =====
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Test

# %%
Y_pred_test_scaled = model.predict([X_test_enc_scaled, Y_test_dec_in_scaled])
print(f"Prediction Shape: {Y_pred_test_scaled.shape}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# Prediction Shape: (164, 2, 2)

# %%
# แปลงค่ากลับเป็นค่าเดิม
Y_pred_test = scaler_dec.inverse_transform(Y_pred_test_scaled.reshape(-1, Y_pred_test_scaled.shape[-1])).reshape(Y_pred_test_scaled.shape)

# แปลงค่าจริงกลับเป็นค่าเดิม
Y_test_dec_out_original = scaler_dec.inverse_transform(Y_test_dec_out_scaled.reshape(-1, Y_test_dec_out_scaled.shape[-1])).reshape(Y_test_dec_out_scaled.shape)
Y_test_dec_out_original.shape
# Out:
# (164, 2, 2)

# %%
Y_test_dec_out_original[: , 0 , 0]
# Out:
# array([22.40603685, 27.19677893, 20.45692979, 18.87432652, 24.07146025,
#        22.10735173, 20.98958298, 24.3699331 , 23.36259973, 21.66924882,
#        20.15985774, 24.38911712, 23.86903882, 22.29543921, 26.11296204,
#        20.20618023, 19.22274747, 20.81823755, 22.03996663, 22.54775264,
#        21.50940757, 22.62768779, 19.35310708, 24.67725564, 21.55991586,
#        23.89427234, 22.28158365, 22.4471003 , 22.61161651, 22.30703255,
#        22.63765775, 23.95219501, 21.6297082 , 22.59856445, 20.9461084 ,
#        23.95198516, 19.66630108, 24.56948113, 20.83699384, 18.0066788 ,
#        21.07658143, 19.4116514 , 22.40967625, 19.3790414 , 19.74910154,
#        16.82085752, 19.65510075, 15.67304489, 17.31541534, 21.96780616,
#        21.98368219, 21.22946151, 18.41242806, 20.22017056, 20.2789892 ,
#        17.94146272, 23.23839162, 21.9611355 , 19.74071891, 20.21408276,
#        20.55617463, 16.03647751, 19.60757678, 18.72139874, 18.06701923,
#        19.49441146, 23.63980273, 21.31540148, 18.88211546, 21.16187105,
#        22.80912507, 21.85486879, 20.12152934, 18.70654315, 21.39649293,
#        20.78812826, 21.79413638, 21.2781665 , 22.11248057, 18.9499346 ,
#        22.6636986 , 20.43408816, 24.20085927, 18.68487715, 23.54955852,
#        20.48928922, 18.80792229, 19.16172606, 19.50898577, 21.0196322 ,
#        21.24002206, 19.07142586, 20.19600823, 24.55655878, 23.75580605,
#        21.2034612 , 20.43829854, 20.63520621, 21.656396  , 18.41934581,
#        19.98709258, 17.20292512, 21.3781087 , 21.91493335, 19.6963453 ,
#        23.85415374, 18.29938322, 17.86815821, 21.29305051, 22.98681384,
#        24.31016009, 20.07542603, 23.20263338, 21.02150381, 20.80767127,
#        22.97579083, 22.56978532, 18.17013057, 24.33486051, 24.2018996 ,
#        20.25158296, 22.35634323, 22.61584228, 22.21317444, 20.65624189,
#        20.47959176, 21.83865812, 24.30307369, 23.11356687, 21.35476997,
#        23.70988864, 16.54073819, 24.60750554, 18.90349441, 21.7317634 ,
#        20.29178246, 20.01696785, 25.00390222, 21.82345089, 23.5291298 ,
#        22.82019083, 23.94664171, 23.22532675, 20.58539284, 25.22415303,
#        22.32487234, 20.28048789, 22.61916355, 26.55910742, 25.3406527 ,
#        23.02592926, 23.10812076, 23.24712233, 28.12797347, 24.82273736,
#        25.00361757, 26.2890228 , 24.79118446, 23.88087548, 24.09179181,
#        24.42697349, 24.58154339, 26.19716075, 24.93178371])

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 1, figsize=(10,8), sharex=True)

axes[0].plot(Y_test_dec_out_original[:, 0, 0], label="Actual Temperature", color="red")
axes[0].plot(Y_pred_test[:, 0, 0], label="Predicted Temperature", linestyle="dashed", color="orange")
axes[0].set_ylabel("Temperature")
axes[0].set_title("Temperature Prediction")
axes[0].legend()

axes[1].plot(Y_test_dec_out_original[:, 0, 1], label="Actual Humidity", color="blue")
axes[1].plot(Y_pred_test[:, 0, 1], label="Predicted Humidity", linestyle="dashed", color="cyan")
axes[1].set_ylabel("Humidity")
axes[1].set_title("Humidity Prediction")
axes[1].legend()

axes[1].set_xlabel("Time Step")

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

mse_temp_scaled = mean_squared_error(Y_test_dec_out_scaled[:, :, 0], Y_pred_test_scaled[:, :, 0])
rmse_temp_scaled = np.sqrt(mse_temp_scaled)
mae_temp_scaled = mean_absolute_error(Y_test_dec_out_scaled[:, :, 0], Y_pred_test_scaled[:, :, 0])

mse_humid_scaled = mean_squared_error(Y_test_dec_out_scaled[:, :, 1], Y_pred_test_scaled[:, :, 1])
rmse_humid_scaled = np.sqrt(mse_humid_scaled)
mae_humid_scaled = mean_absolute_error(Y_test_dec_out_scaled[:, :, 1], Y_pred_test_scaled[:, :, 1])

print("=== Test Score (Before Inverse Transform) ===")
print(f"Temperature - MSE: {mse_temp_scaled:.6f}, RMSE: {rmse_temp_scaled:.6f}, MAE: {mae_temp_scaled:.6f}")
print(f"Humidity - MSE: {mse_humid_scaled:.6f}, RMSE: {rmse_humid_scaled:.6f}, MAE: {mae_humid_scaled:.6f}")
# Out:
# === Test Score (Before Inverse Transform) ===
# Temperature - MSE: 0.033911, RMSE: 0.184151, MAE: 0.148830
# Humidity - MSE: 0.035515, RMSE: 0.188455, MAE: 0.145795

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

mse_temp = mean_squared_error(Y_test_dec_out_original[:, 0, 0], Y_pred_test[:, 0, 0])
rmse_temp = np.sqrt(mse_temp)
mae_temp = mean_absolute_error(Y_test_dec_out_original[:, 0, 0], Y_pred_test[:, 0, 0])

mse_humid = mean_squared_error(Y_test_dec_out_original[:, 0, 1], Y_pred_test[:, 0, 1])
rmse_humid = np.sqrt(mse_humid)
mae_humid = mean_absolute_error(Y_test_dec_out_original[:, 0, 1], Y_pred_test[:, 0, 1])

print("=== Test Score ===")
print(f"Temperature - MSE: {mse_temp:.4f}, RMSE: {rmse_temp:.4f}, MAE: {mae_temp:.4f}")
print(f"Humidity - MSE: {mse_humid:.4f}, RMSE: {rmse_humid:.4f}, MAE: {mae_humid:.4f}")
# Out:
# === Test Score ===
# Temperature - MSE: 32.8558, RMSE: 5.7320, MAE: 4.6528
# Humidity - MSE: 128.3226, RMSE: 11.3280, MAE: 8.7980
