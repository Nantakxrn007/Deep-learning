# %%
import torch 
import torch.nn as nn 
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt

# %%
x_numpy , y_numpy = datasets.make_regression(n_samples=100,n_features=1,noise=20,random_state=2)
plt.scatter(x_numpy,y_numpy)

# %%
X = torch.from_numpy(x_numpy.astype(np.float32))
y = torch.from_numpy(y_numpy.astype(np.float32))
y = y.view(y.shape[0],1)

# %%
# create model 
input_size = X.size()[1]
output_size = 1
model = nn.Linear(input_size,output_size)

learning_rate = 0.01
optim = torch.optim.SGD(model.parameters(),lr=learning_rate)
criterion = nn.MSELoss()

# %%
# training 
n_iter = 10
for epoch in range(n_iter):
    #forward 
    y_predicted = model(X)
    loss = criterion(y_predicted,y)

    #backward 
    loss.backward()

    #update
    optim.step()
    optim.zero_grad()

    print(f'epoch {epoch} , loss {loss}')
    print(y_predicted[0])
    print(y[0])
# Out:
# epoch 0 , loss 521.3861083984375
# tensor([-41.3061], grad_fn=<SelectBackward0>)
# tensor([-39.2811])
# epoch 1 , loss 514.1222534179688
# tensor([-41.5319], grad_fn=<SelectBackward0>)
# tensor([-39.2811])
# epoch 2 , loss 507.167724609375
# tensor([-41.7522], grad_fn=<SelectBackward0>)
# tensor([-39.2811])
# epoch 3 , loss 500.50946044921875
# tensor([-41.9672], grad_fn=<SelectBackward0>)
# tensor([-39.2811])
# epoch 4 , loss 494.13458251953125
# tensor([-42.1770], grad_fn=<SelectBackward0>)
# tensor([-39.2811])
# epoch 5 , loss 488.031005859375
# tensor([-42.3817], grad_fn=<SelectBackward0>)
# tensor([-39.2811])
# epoch 6 , loss 482.1869812011719
# tensor([-42.5815], grad_fn=<SelectBackward0>)
# tensor([-39.2811])
# epoch 7 , loss 476.5914001464844
# tensor([-42.7764], grad_fn=<SelectBackward0>)
# tensor([-39.2811])
# epoch 8 , loss 471.2335510253906
# tensor([-42.9666], grad_fn=<SelectBackward0>)
# tensor([-39.2811])
# epoch 9 , loss 466.103271484375
# tensor([-43.1521], grad_fn=<SelectBackward0>)
# tensor([-39.2811])

# %%
plt.scatter(x_numpy,y_numpy)
plt.plot(x_numpy,y_predicted.detach().numpy())
